# %%
# !pip install transformers datasets torch  --q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# !pip install SpeechRecognition
# !pip install ffmpeg
# Out:
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.12.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from SpeechRecognition) (4.12.2)
# Downloading SpeechRecognition-3.12.0-py3-none-any.whl (32.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 50.3 MB/s eta 0:00:00
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.12.0
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=6c0fd561a17d57aec439d13de4a1aef6722c7e067bb5610d1772bbb2d41ae65d
#   Stored in directory: /root/.cache/pip/wheels/8e/7a/69/cd6aeb83b126a7f04cbe7c9d929028dc52a6e7d525ff56003a
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4

# %%
import subprocess

result = subprocess.run(['ffmpeg', '-version'], capture_output=True, text=True)
print(result.stdout)
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
# built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
# libavutil      56. 70.100 / 56. 70.100
# libavcodec     58.134.100 / 58.134.100
# libavformat    58. 76.100 / 58. 76.100
# libavdevice    58. 13.100 / 58. 13.100
# libavfilter     7.110.100 /  7.110.100
# libswscale      5.  9.100 /  5.  9.100
# libswresample   3.  9.100 /  3.  9.100
# libpostproc    55.  9.100 / 55.  9.100

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = "drive/MyDrive/Speech2Text/dataset/"

if not os.path.exists(path):
    try:
        os.makedirs(path)
        print(f"The directory '{path}' has been created successfully.")
    except OSError as e:
        print(f"Error creating directory: {e}")
else:
    print(f"The directory '{path}' already exists.")
# Out:
# The directory 'drive/MyDrive/Speech2Text/dataset/' already exists.

# %%
import subprocess

# convert mp3 to wav file
subprocess.call(['ffmpeg', '-i', f"{path}/grandfather. 2015-10-09_20'20'35'.mp3",
                 f'{path}/converted_to_wav_file.wav'])
# Out:
# 1

# %%
# import IPython

# IPython.display.Audio(SPEECH_FILE)

# %%
import soundfile as sf

def load_audio(file_path):
    speech, sampling_rate = sf.read(file_path)
    return {"speech": speech, "sampling_rate": sampling_rate}

main_path = '/content/drive/MyDrive/Speech2Text/dataset/madar0'
audio_data = load_audio(f'{main_path}/Lab41-SRI-VOiCES-madar.wav')
print(f"Original sampling rate: {audio_data['sampling_rate']}")
# Out:
# Original sampling rate: 44100

# %%
import torch
print(torch.cuda.is_available())

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# False
# Speech2TextForConditionalGeneration(
#   (model): Speech2TextModel(
#     (encoder): Speech2TextEncoder(
#       (conv): Conv1dSubsampler(
#         (conv_layers): ModuleList(
#           (0): Conv1d(80, 1024, kernel_size=(5,), stride=(2,), padding=(2,))
#           (1): Conv1d(512, 512, kernel_size=(5,), stride=(2,), padding=(2,))
#         )
#       )
#       (embed_positions): Speech2TextSinusoidalPositionalEmbedding()
#       (layers): ModuleList(
#         (0-11): 12 x Speech2TextEncoderLayer(
#           (self_attn): Speech2TextAttention(
#             (k_proj): Linear(in_features=256, out_features=256, bias=True)
#             (v_proj): Linear(in_features=256, out_features=256, bias=True)
#             (q_proj): Linear(in_features=256, out_features=256, bias=True)
#             (out_proj): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): ReLU()
#           (fc1): Linear(in_features=256, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=256, bias=True)
#           (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): Speech2TextDecoder(
#       (embed_tokens): Embedding(10000, 256, padding_idx=1)
#       (embed_positions): Speech2TextSinusoidalPositionalEmbedding()
#       (layers): ModuleList(
#         (0-5): 6 x Speech2TextDecoderLayer(
#           (self_attn): Speech2TextAttention(
#             (k_proj): Linear(in_features=256, out_features=256, bias=True)
#             (v_proj): Linear(in_features=256, out_features=256, bias=True)
#             (q_proj): Linear(in_features=256, out_features=256, bias=True)
#             (out_proj): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): Speech2TextAttention(
#             (k_proj): Linear(in_features=256, out_features=256, bias=True)
#             (v_proj): Linear(in_features=256, out_features=256, bias=True)
#             (q_proj): Linear(in_features=256, out_features=256, bias=True)
#             (out_proj): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=256, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=256, bias=True)
#           (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=256, out_features=10000, bias=False)
# )

# %%
import librosa

def resample_audio(audio_data):
    speech = audio_data["speech"]
    sampling_rate = audio_data["sampling_rate"]
    if sampling_rate != 16000:
        speech = librosa.resample(speech, orig_sr=sampling_rate, target_sr=16000)
    return {"speech": speech, "sampling_rate": 16000}

# from scipy.signal import resample

# def resample_audio(audio_data):
#     speech = audio_data["speech"]
#     sampling_rate = audio_data["sampling_rate"]
#     if sampling_rate != 16000:
#         num_samples = int(len(speech) * 16000 / sampling_rate)
#         speech = resample(speech, num_samples)
#     return {"speech": speech, "sampling_rate": 16000}

# resampled_audio = resample_audio(audio_data)
# print(f"Resampled sampling rate: {resampled_audio['sampling_rate']}")

# %%
from transformers import Speech2TextProcessor, Speech2TextForConditionalGeneration
import torch
from IPython.display import Audio

def preprocess_audio(file_path):
    # audio_data = load_audio(file_path)

    audio_data, rate = librosa.load(file_path, sr=16000)
    Audio(audio_data, rate=rate)
    # resampled_audio = resample_audio(audio_data)

    processor = Speech2TextProcessor.from_pretrained("facebook/s2t-small-librispeech-asr")
    inputs = processor(resampled_audio["speech"], sampling_rate=resampled_audio["sampling_rate"], return_tensors="pt")
    return inputs

model_name = "facebook/s2t-small-librispeech-asr"
model = Speech2TextForConditionalGeneration.from_pretrained(model_name)

main_path = '/content/drive/MyDrive/Speech2Text/dataset/madar0'
inputs = preprocess_audio(f'{main_path}/Lab41-SRI-VOiCES-madar.wav')
with torch.no_grad():
    logits = model(**inputs).logits

processor = Speech2TextProcessor.from_pretrained(model_name)
transcription = processor.batch_decode(logits, skip_special_tokens=True)[0]
print(f"Transcription: {transcription}")
# Out:
# Some weights of Speech2TextForConditionalGeneration were not initialized from the model checkpoint at facebook/s2t-small-librispeech-asr and are newly initialized: ['model.decoder.embed_positions.weights', 'model.encoder.embed_positions.weights']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-62-7bf676e0a251> in <cell line: 20>()
#      18
#      19 main_path = '/content/drive/MyDrive/Speech2Text/dataset/madar0'
# ---> 20 inputs = preprocess_audio(f'{main_path}/Lab41-SRI-VOiCES-madar.wav')
#      21 with torch.no_grad():
#      22     logits = model(**inputs).logits
#
# <ipython-input-62-7bf676e0a251> in preprocess_audio(file_path)
#       8     audio_data, rate = librosa.load(file_path, sr=16000)
#       9     Audio(audio_data, rate=rate)
# ---> 10     resampled_audio = resample_audio(audio_data)
#      11
#      12     processor = Speech2TextProcessor.from_pretrained("facebook/s2t-small-librispeech-asr")
#
# <ipython-input-61-c43adb427837> in resample_audio(audio_data)
#      15
#      16 def resample_audio(audio_data):
# ---> 17     speech = audio_data["speech"]
#      18     sampling_rate = audio_data["sampling_rate"]
#      19     if sampling_rate != 16000:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
from transformers import Speech2TextProcessor, Speech2TextForConditionalGeneration
import torch
import librosa

model_name = "facebook/s2t-small-librispeech-asr"
model = Speech2TextForConditionalGeneration.from_pretrained(model_name)
processor = Speech2TextProcessor.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

def load_audio(file_path):
    speech, sampling_rate = librosa.load(file_path, sr=None)
    return {"speech": speech, "sampling_rate": sampling_rate}

def resample_audio(audio_data):
    speech = audio_data["speech"]
    sampling_rate = audio_data["sampling_rate"]
    if sampling_rate != 16000:
        speech = librosa.resample(speech, orig_sr=sampling_rate, target_sr=16000)
    return {"speech": speech, "sampling_rate": 16000}

def transcribe_audio(file_path):
    audio_data = load_audio(file_path)
    resampled_audio = resample_audio(audio_data)

    inputs = processor(resampled_audio["speech"], sampling_rate=resampled_audio["sampling_rate"], return_tensors="pt", padding=True)
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        logits = model(**inputs).logits

    transcription = processor.batch_decode(logits, skip_special_tokens=True)[0]
    return transcription

main_path = '/content/drive/MyDrive/Speech2Text/dataset/madar0'
audio_file = f"{main_path}/output.wav"
input_path = f'{main_path}/Lab41-SRI-VOiCES-madar.wav'
transcription = transcribe_audio(input_path)
print(transcription)
# Out:
# Some weights of Speech2TextForConditionalGeneration were not initialized from the model checkpoint at facebook/s2t-small-librispeech-asr and are newly initialized: ['model.decoder.embed_positions.weights', 'model.encoder.embed_positions.weights']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-c43adb427837> in <cell line: 39>()
#      37 audio_file = f"{main_path}/output.wav"
#      38 input_path = f'{main_path}/Lab41-SRI-VOiCES-madar.wav'
# ---> 39 transcription = transcribe_audio(input_path)
#      40 print(transcription)
#
# <ipython-input-61-c43adb427837> in transcribe_audio(file_path)
#      29
#      30     with torch.no_grad():
# ---> 31         logits = model(**inputs).logits
#      32
#      33     transcription = processor.batch_decode(logits, skip_special_tokens=True)[0]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/speech_to_text/modeling_speech_to_text.py in forward(self, input_features, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1293                 )
#    1294
# -> 1295         outputs = self.model(
#    1296             input_features,
#    1297             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/speech_to_text/modeling_speech_to_text.py in forward(self, input_features, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1175
#    1176         # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1177         decoder_outputs = self.decoder(
#    1178             input_ids=decoder_input_ids,
#    1179             attention_mask=decoder_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/speech_to_text/modeling_speech_to_text.py in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     959             input_shape = inputs_embeds.size()[:-1]
#     960         else:
# --> 961             raise ValueError("You have to specify either decoder_input_ids or decoder_inputs_embeds")
#     962
#     963         # past_key_values_length
#
# ValueError: You have to specify either decoder_input_ids or decoder_inputs_embeds
